# %%
def count_vowels(s: str):
    pass

def test_count_vowels():
    assert count_vowels("Anis") == 2
    assert count_vowels("Benoit") == 3
    assert count_vowels("Jeremie") == 4


test_count_vowels()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-2-d9ec9a2551b9> in <module>
#       8
#       9
# ---> 10 test_count_vowels()
#
# <ipython-input-2-d9ec9a2551b9> in test_count_vowels()
#       3
#       4 def test_count_vowels():
# ----> 5     assert count_vowels("Anis") == 2
#       6     assert count_vowels("Benoit") == 3
#       7     assert count_vowels("Jeremie") == 4
#
# AssertionError:

# %%
def my_name_is(text: str):
    pass


def test_my_name_is():
    assert (
        my_name_is("Je m'appele Benoit.    j'ai 26 ans.  je passe un test.salut.")
        == "Je m'appele Benoit.    J'ai 26 ans.  Je passe un test.Salut."
    )


test_my_name_is()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-7-d507a1d848f6> in <module>
#      10
#      11
# ---> 12 test_my_name_is()
#
# <ipython-input-7-d507a1d848f6> in test_my_name_is()
#       6     assert (
#       7         my_name_is("Je m'appele Benoit.    j'ai 26 ans.  je passe un test.salut.")
# ----> 8         == "Je m'appele Benoit.    J'ai 26 ans.  Je passe un test.Salut."
#       9     )
#      10
#
# AssertionError:

# %%
def transpose():
    pass


def test_transpose():
    assert transpose([[1, 2], ["a", "b"]]) == [(1, "a"), (2, "b")]
    assert transpose([[1, 2, 3], ["a", "b", "c"]]) == [(1, "a"), (2, "b"), (3, "c")]

test_transpose()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-7618334f586c> in <module>
#       7     assert transpose([[1, 2, 3], ["a", "b", "c"]]) == [(1, "a"), (2, "b"), (3, "c")]
#       8
# ----> 9 test_transpose()
#
# <ipython-input-8-7618334f586c> in test_transpose()
#       4
#       5 def test_transpose():
# ----> 6     assert transpose([[1, 2], ["a", "b"]]) == [(1, "a"), (2, "b")]
#       7     assert transpose([[1, 2, 3], ["a", "b", "c"]]) == [(1, "a"), (2, "b"), (3, "c")]
#       8
#
# TypeError: transpose() takes 0 positional arguments but 1 was given
